# %% [markdown]
# Setup the Keras Environment

# %%
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# Construct the Encoder

# %%
latent_dim = 1

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z = layers.Dense(latent_dim, name="z")(x)
encoder = keras.Model(encoder_inputs, z, name="encoder")
encoder.summary()
# Out:
# WARNING:tensorflow:From g:\UManitoba\DGM\Codes\.venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 14, 14, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 16)                50192
#
#  z (Dense)                   (None, 1)                 17
#
# =================================================================
# Total params: 69025 (269.63 KB)
# Trainable params: 69025 (269.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Construct the Decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1)]               0
#
#  dense_1 (Dense)             (None, 3136)              6272
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 61953 (242.00 KB)
# Trainable params: 61953 (242.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Define the AE as a Class with Custom Training

# %%
class AE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            #self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            total_loss = reconstruction_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        #self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            #"kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# Train the Model

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

ae = AE(encoder, decoder)
ae.compile(optimizer=keras.optimizers.Adam())
history = ae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 39s 63ms/step - loss: 250.7844 - reconstruction_loss: 206.4964
# Epoch 2/30
# 547/547 [==============================] - 36s 66ms/step - loss: 184.4889 - reconstruction_loss: 183.2489
# Epoch 3/30
# 547/547 [==============================] - 32s 59ms/step - loss: 178.7305 - reconstruction_loss: 177.3705
# Epoch 4/30
# 547/547 [==============================] - 33s 61ms/step - loss: 173.3765 - reconstruction_loss: 172.4434
# Epoch 5/30
# 547/547 [==============================] - 39s 72ms/step - loss: 170.2504 - reconstruction_loss: 169.6911
# Epoch 6/30
# 547/547 [==============================] - 113s 206ms/step - loss: 168.1694 - reconstruction_loss: 168.1385
# Epoch 7/30
# 547/547 [==============================] - 69s 126ms/step - loss: 166.9862 - reconstruction_loss: 166.9230
# Epoch 8/30
# 547/547 [==============================] - 55s 100ms/step - loss: 166.3423 - reconstruction_loss: 166.1356
# Epoch 9/30
# 547/547 [==============================] - 68s 125ms/step - loss: 165.5179 - reconstruction_loss: 165.4584
# Epoch 10/30
# 547/547 [==============================] - 75s 136ms/step - loss: 165.2372 - reconstruction_loss: 164.8687
# Epoch 11/30
# 547/547 [==============================] - 59s 108ms/step - loss: 164.3062 - reconstruction_loss: 164.4683
# Epoch 12/30
# 547/547 [==============================] - 60s 110ms/step - loss: 163.9010 - reconstruction_loss: 164.0241
# Epoch 13/30
# 547/547 [==============================] - 61s 111ms/step - loss: 163.5567 - reconstruction_loss: 163.5557
# Epoch 14/30
# 547/547 [==============================] - 49s 90ms/step - loss: 163.1738 - reconstruction_loss: 163.0435
# Epoch 15/30
# 547/547 [==============================] - 49s 90ms/step - loss: 162.8556 - reconstruction_loss: 162.7267
# Epoch 16/30
# 547/547 [==============================] - 49s 90ms/step - loss: 162.3378 - reconstruction_loss: 162.4709
# Epoch 17/30
# 547/547 [==============================] - 46s 84ms/step - loss: 162.1883 - reconstruction_loss: 162.0887
# Epoch 18/30
# 547/547 [==============================] - 47s 85ms/step - loss: 161.7090 - reconstruction_loss: 161.7594
# Epoch 19/30
# 547/547 [==============================] - 47s 86ms/step - loss: 161.6752 - reconstruction_loss: 161.4772
# Epoch 20/30
# 547/547 [==============================] - 47s 85ms/step - loss: 161.0704 - reconstruction_loss: 161.1815
# Epoch 21/30
# 547/547 [==============================] - 54s 99ms/step - loss: 161.1449 - reconstruction_loss: 160.9241
# Epoch 22/30
# 547/547 [==============================] - 45s 82ms/step - loss: 160.7963 - reconstruction_loss: 160.6081
# Epoch 23/30
# 547/547 [==============================] - 46s 83ms/step - loss: 160.6248 - reconstruction_loss: 160.4211
# Epoch 24/30
# 547/547 [==============================] - 44s 81ms/step - loss: 159.8846 - reconstruction_loss: 160.1066
# Epoch 25/30
# 547/547 [==============================] - 45s 82ms/step - loss: 160.0928 - reconstruction_loss: 160.0796
# Epoch 26/30
# 547/547 [==============================] - 47s 86ms/step - loss: 160.1052 - reconstruction_loss: 159.8651
# Epoch 27/30
# 547/547 [==============================] - 47s 87ms/step - loss: 159.6537 - reconstruction_loss: 159.5763
# Epoch 28/30
# 547/547 [==============================] - 45s 82ms/step - loss: 159.1776 - reconstruction_loss: 159.3238
# Epoch 29/30
# 547/547 [==============================] - 51s 92ms/step - loss: 158.9096 - reconstruction_loss: 159.1744
# Epoch 30/30
# 547/547 [==============================] - 48s 87ms/step - loss: 159.1651 - reconstruction_loss: 159.0943

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'reconstruction_loss'])

# %% [markdown]
# Plot the loss function

# %%
# summarize history for accuracy
plt.plot(history.history['reconstruction_loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Save the Model Weights

# %%
ae.save_weights('./P1E2D1_AE_mnist_latent2.weights.h5')
# Out:
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.

# %% [markdown]
# Display a grid of sampled digits

# %%
def plot_latent_space(ae, n=50, figsize=15):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size, n * digit_size))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    
    for i, xi in enumerate(grid_x):
        z_sample = np.array([[xi]])
        x_decoded = ae.decoder.predict(z_sample, verbose=0)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[
            0 : digit_size,
            i * digit_size : (i + 1) * digit_size,
        ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.xlabel("z")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()

plot_latent_space(ae)

# %% [markdown]
# Display how the latent space clusters different digit classes

# %%
def plot_label_clusters(ae, data, labels):
    # display a 2D plot of the digit classes in the latent space
    z_mean = ae.encoder.predict(data, verbose=0)
    plt.figure(figsize=(12, 3))
    plt.scatter(z_mean[:, 0], np.zeros(len(z_mean)), c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.show()


(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(ae, x_train, y_train)
