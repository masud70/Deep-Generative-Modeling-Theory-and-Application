# %% [markdown]
# Setup the Keras Environment

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras import layers
# Out:
# WARNING:tensorflow:From g:\UManitoba\DGM\Codes\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Construct the Encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z = layers.Dense(latent_dim, name="z")(x)
encoder = keras.Model(encoder_inputs, z, name="encoder")
encoder.summary()
# Out:
# WARNING:tensorflow:From g:\UManitoba\DGM\Codes\.myenv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 14, 14, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)          18496
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 16)                50192
#
#  z (Dense)                   (None, 2)                 34
#
# =================================================================
# Total params: 69042 (269.70 KB)
# Trainable params: 69042 (269.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Construct the Decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Define the AE as a Class with Custom Training

# %%
class AE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        #self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            #self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            total_loss = reconstruction_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        #self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            #"kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# Train the Model

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

ae = AE(encoder, decoder)
ae.compile(optimizer=keras.optimizers.Adam())
history = ae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/30
# 547/547 [==============================] - 42s 70ms/step - loss: 247.7798 - reconstruction_loss: 198.2692
# Epoch 2/30
# 547/547 [==============================] - 35s 63ms/step - loss: 165.6975 - reconstruction_loss: 162.6791
# Epoch 3/30
# 547/547 [==============================] - 35s 65ms/step - loss: 156.0438 - reconstruction_loss: 154.6864
# Epoch 4/30
# 547/547 [==============================] - 46s 84ms/step - loss: 151.4750 - reconstruction_loss: 150.8439
# Epoch 5/30
# 547/547 [==============================] - 50s 92ms/step - loss: 149.2420 - reconstruction_loss: 148.6644
# Epoch 6/30
# 547/547 [==============================] - 74s 136ms/step - loss: 147.5359 - reconstruction_loss: 147.1374
# Epoch 7/30
# 547/547 [==============================] - 51s 94ms/step - loss: 145.8237 - reconstruction_loss: 146.1358
# Epoch 8/30
# 547/547 [==============================] - 49s 90ms/step - loss: 145.2182 - reconstruction_loss: 145.0860
# Epoch 9/30
# 547/547 [==============================] - 61s 112ms/step - loss: 144.5377 - reconstruction_loss: 144.3186
# Epoch 10/30
# 547/547 [==============================] - 52s 94ms/step - loss: 143.4560 - reconstruction_loss: 143.5843
# Epoch 11/30
# 547/547 [==============================] - 47s 86ms/step - loss: 142.8267 - reconstruction_loss: 142.9980
# Epoch 12/30
# 547/547 [==============================] - 45s 83ms/step - loss: 142.5082 - reconstruction_loss: 142.5406
# Epoch 13/30
# 547/547 [==============================] - 92s 168ms/step - loss: 141.9246 - reconstruction_loss: 142.0067
# Epoch 14/30
# 547/547 [==============================] - 58s 106ms/step - loss: 141.4701 - reconstruction_loss: 141.6160
# Epoch 15/30
# 547/547 [==============================] - 48s 89ms/step - loss: 141.3762 - reconstruction_loss: 141.2178
# Epoch 16/30
# 547/547 [==============================] - 39s 71ms/step - loss: 141.0409 - reconstruction_loss: 140.7990
# Epoch 17/30
# 547/547 [==============================] - 38s 70ms/step - loss: 140.6207 - reconstruction_loss: 140.5417
# Epoch 18/30
# 547/547 [==============================] - 37s 67ms/step - loss: 140.3241 - reconstruction_loss: 140.2103
# Epoch 19/30
# 547/547 [==============================] - 35s 65ms/step - loss: 139.9769 - reconstruction_loss: 139.9491
# Epoch 20/30
# 547/547 [==============================] - 34s 63ms/step - loss: 139.5738 - reconstruction_loss: 139.6082
# Epoch 21/30
# 547/547 [==============================] - 37s 68ms/step - loss: 139.1958 - reconstruction_loss: 139.3855
# Epoch 22/30
# 547/547 [==============================] - 35s 64ms/step - loss: 139.3311 - reconstruction_loss: 139.3064
# Epoch 23/30
# 547/547 [==============================] - 36s 65ms/step - loss: 138.8140 - reconstruction_loss: 138.9823
# Epoch 24/30
# 547/547 [==============================] - 36s 67ms/step - loss: 138.8200 - reconstruction_loss: 138.7514
# Epoch 25/30
# 547/547 [==============================] - 35s 65ms/step - loss: 138.9820 - reconstruction_loss: 138.6794
# Epoch 26/30
# 547/547 [==============================] - 34s 63ms/step - loss: 138.1395 - reconstruction_loss: 138.4494
# Epoch 27/30
# 547/547 [==============================] - 35s 64ms/step - loss: 138.2223 - reconstruction_loss: 138.1860
# Epoch 28/30
# 547/547 [==============================] - 35s 65ms/step - loss: 137.6823 - reconstruction_loss: 138.0696
# Epoch 29/30
# 547/547 [==============================] - 35s 64ms/step - loss: 137.8234 - reconstruction_loss: 137.9131
# Epoch 30/30
# 547/547 [==============================] - 36s 65ms/step - loss: 137.5005 - reconstruction_loss: 137.8150

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'reconstruction_loss'])

# %% [markdown]
# Plot the loss function

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['reconstruction_loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Save the Model Weights

# %%
ae.save_weights('./AE_mnist_latent2.weights.h5')
# Out:
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.

# %% [markdown]
# Display a grid of sampled digits

# %%
import matplotlib.pyplot as plt


def plot_latent_space(ae, n=30, figsize=15):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = ae.decoder.predict(z_sample, verbose=0)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(ae)

# %% [markdown]
# Display how the latent space clusters different digit classes

# %%
def plot_label_clusters(ae, data, labels):
    # display a 2D plot of the digit classes in the latent space
    z_mean = ae.encoder.predict(data, verbose=0)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.show()


(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(ae, x_train, y_train)
